# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn import metrics

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('../Datasets/ALNY_processed.csv')
df1 = df.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
def build_and_train_model(X_train, y_train):
    model = Sequential()
    model.add(GRU(64, input_shape=(100, 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')  
    model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)
    return model

# %%
def predict_future(model, last_data, n_future, n_steps=100):
    temp_input = list(last_data)
    temp_input = temp_input[0].tolist()
    
    lst_output = []
    i = 0
    while i < n_future:
        if len(temp_input) > n_steps:
            x_input = np.array(temp_input[1:])
            x_input = x_input.reshape(1, -1)
            x_input = x_input.reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            temp_input = temp_input[1:]
            lst_output.extend(yhat.tolist())
            i += 1
        else:
            x_input = np.array(temp_input).reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            lst_output.extend(yhat.tolist())
            i += 1
            
    return np.array(lst_output).reshape(-1, 1)

# %%
def plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, train_size, test_size, title):
    train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
    plt.plot(train_data_index, scaler.inverse_transform(train_data))

    test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
    plt.plot(test_data_index, scaler.inverse_transform(test_data))

    test_pred_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
    plt.plot(test_pred_index,scaler.inverse_transform(y_pred))

    prediect_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
    plt.plot(prediect_data_index_30, scaler.inverse_transform(lst_output[:30]))

    prediect_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
    plt.plot(prediect_data_index_60, scaler.inverse_transform(lst_output[30:60]))

    prediect_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
    plt.plot(prediect_data_index_90, scaler.inverse_transform(lst_output[60:90]))

    plt.legend(['Train', 'Test', 'Predict', 'Predict30days', 'Predict60days', 'Predict90days'])
    plt.title(title)
    plt.show()

# %%
def evaluate_model(y_test, y_pred):
    mae = metrics.mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    mape = metrics.mean_absolute_percentage_error(y_test, y_pred)*100
    return mae, rmse, mape

# %%
ratios = [0.7, 0.8, 0.6]
time_step = 100

# Results dictionary to store evaluation metrics for each ratio
results = {}

# %%
for ratio in ratios:
    # Chia dữ liệu thành tập huấn luyện và kiểm tra
    training_size = int(len(df1) * ratio)
    test_size = len(df1) - training_size
    train_data, test_data = df1[0:training_size,:], df1[training_size:len(df1),:1]

    # Tạo tập huấn luyện và kiểm tra
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, y_test = create_dataset(test_data, time_step)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Xây dựng và huấn luyện mô hình
    model = build_and_train_model(X_train, y_train)

    # Dự đoán
    y_pred = model.predict(X_test)

    # Đảo ngược quá trình chuẩn hóa
    y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_pred_inv = scaler.inverse_transform(y_pred)

    # Đánh giá mô hình
    mae, rmse, mape = evaluate_model(y_test_inv, y_pred_inv)
    results[f'Ratio {int(ratio*10)}/{10-int(ratio*10)}'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}

    # Dự đoán các giá trị trong tương lai
    last_data = test_data[-time_step:].reshape(1, -1)
    lst_output = predict_future(model, last_data, 90)

    # Vẽ biểu đồ
    plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, training_size, test_size, f"Train/Test Ratio: {int(ratio*10)}/{10-int(ratio*10)}")

# In kết quả đánh giá
for ratio, metrics in results.items():
    print(f'{ratio}: MAE = {metrics["MAE"]}, RMSE = {metrics["RMSE"]}, MAPE = {metrics["MAPE"]}')
# Out:
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0479
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0046
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0025
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0014
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0011
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.2963e-04
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.5586e-04
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.8976e-04
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.6041e-04
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 7.3361e-04
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.8023e-04
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.0455e-04
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.1952e-04
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.2661e-04
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.8900e-04
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 9.3834e-04
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.0197e-04
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.1553e-04
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.8241e-04
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.3060e-04
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0010
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.1842e-04
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.9837e-04
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.5328e-04
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.4996e-04
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.7612e-04
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.7987e-04
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.8623e-04
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.4391e-04
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.0856e-04
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.2262e-04
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.1849e-04
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.1949e-04
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.1968e-04
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.2047e-04
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.6364e-04
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.9119e-04
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.4024e-04
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.9373e-04
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 6.4049e-04
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.2685e-04
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.6895e-04
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.7502e-04
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.1993e-04
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.4988e-04
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.1192e-04
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.7534e-04
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.2690e-04
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.0253e-04
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.2264e-04
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.5681e-04
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.2746e-04
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4804e-04
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.0574e-04
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.3078e-04
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.9608e-04
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.2848e-04
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.1704e-04
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4536e-04
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.2958e-04
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.0047e-04
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.1047e-04
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.7977e-04
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.7933e-04
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.6303e-04
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1183e-04
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.0964e-04
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.7702e-04
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.9540e-04
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.1086e-04
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.5607e-04
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.6776e-04
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.0682e-04
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.8890e-04
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1311e-04
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.0433e-04
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.7407e-04
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.6828e-04
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.2072e-04
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.3175e-04
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.4858e-04
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.5686e-04
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.7276e-04
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.7082e-04
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.5199e-04
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.5227e-04
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.5621e-04
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.2638e-04
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.8822e-04
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 4.3480e-04
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 4.6673e-04
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 4.3367e-04
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 4.3528e-04
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.0576e-04
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.4249e-04
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.2975e-04
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.6396e-04
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.6959e-04
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.1097e-04
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 7.6079e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 0.2196
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0190
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0075
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0040
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0017
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0013
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0016
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.0011
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0013
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0013
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 9.5407e-04
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0010
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0013
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0010
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0010
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.0013
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 8.7398e-04
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 8.3514e-04
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0010
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 7.9779e-04
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 9.7680e-04
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 8.6149e-04
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 7.5590e-04
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 8.7739e-04
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0010
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 7.7509e-04
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 9.3097e-04
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 9.7743e-04
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 7.6148e-04
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0011
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.0802e-04
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 7.4119e-04
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 7.2504e-04
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 7.6765e-04
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 6.9499e-04
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0011
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 7.9013e-04
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 8.1635e-04
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 6.6915e-04
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 5.4128e-04
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 6.6834e-04
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 9.3976e-04
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 8.1648e-04
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 5.8341e-04
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 7.4955e-04
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 5.5560e-04
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 5.4366e-04
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.0850e-04
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 6.4963e-04
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 7.3530e-04
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 5.3785e-04
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 5.3247e-04
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 6.2093e-04
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 7.7442e-04
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 6.7067e-04
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 9.4026e-04
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 8.4825e-04
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 5.6141e-04
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 5.9626e-04
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 7.7814e-04
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 6.3356e-04
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 5.3990e-04
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 8.4547e-04
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 8.9296e-04
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 6.6235e-04
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 5.6960e-04
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 5.9547e-04
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 4.8553e-04
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 4.5498e-04
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 7.6442e-04
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 6.0730e-04
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 4.8288e-04
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.0815e-04
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 6.9050e-04
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 6.6717e-04
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.7652e-04
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 6.3409e-04
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 6.0411e-04
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 5.6710e-04
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 5.8592e-04
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 4.7732e-04
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 6.0399e-04
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 5.1510e-04
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 5.2615e-04
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 5.0992e-04
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 5.9033e-04
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 6.4574e-04
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 5.3168e-04
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 4.5718e-04
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 6.7416e-04
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 4.7305e-04
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.8995e-04
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 6.1196e-04
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.7104e-04
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 5.4517e-04
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 7.2242e-04
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 5.0993e-04
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 4.8933e-04
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 6.3236e-04
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 5.5112e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 0.0853
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0112
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0045
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0023
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0012
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 8.0273e-04
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.0845e-04
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 7.2618e-04
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 6.2756e-04
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 6.8949e-04
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 6.1561e-04
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 7.1566e-04
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 5.1775e-04
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 6.2440e-04
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 5.5262e-04
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 5.1403e-04
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 4.8953e-04
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.6670e-04
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.1979e-04
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.1279e-04
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.8395e-04
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.2850e-04
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.7340e-04
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.1944e-04
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.1632e-04
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.8954e-04
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.5142e-04
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.6839e-04
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.4168e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 3.9349e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.2352e-04
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.2973e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.1845e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.1091e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.1347e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.1919e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.7588e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.9020e-04
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.1965e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.6712e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3.9604e-04
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.7816e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.1114e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.8477e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 3.6217e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3.7598e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.1056e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.2015e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 3.4585e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.8429e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.2120e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.6495e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.9647e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 3.9149e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 3.5104e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.7106e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3.4844e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.3069e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.6172e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.8632e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.5965e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.7107e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3.3847e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.7400e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 3.5543e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 3.6645e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 3.7663e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.1642e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.7264e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.7304e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.4037e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.5762e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.2880e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.4848e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.1637e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.7673e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.0362e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.4341e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.1985e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.4390e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.4826e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.2148e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.1854e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.3380e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.0872e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.3669e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.5146e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.7635e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.6927e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.5953e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.0897e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.4676e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 3.7921e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 3.6325e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.4056e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 3.0202e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.2504e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.2375e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.3073e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.4030e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Ratio 7/3: MAE = 2.709735063825335, RMSE = 3.625355717607697, MAPE = 1.4031716934451575
# Ratio 8/2: MAE = 2.2735334035045702, RMSE = 3.3714518259468833, MAPE = 1.2688395816901452
# Ratio 6/4: MAE = 2.983503692142548, RMSE = 4.979750912881434, MAPE = 1.5325027647583054
