# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn import metrics

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('../Datasets/REGN_processed.csv')
df1 = df.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
def build_and_train_model(X_train, y_train, X_test, y_test):
    model = Sequential()
    model.add(GRU(64, input_shape=(100, 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')  
    model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)
    return model

# %%
def predict_future(model, last_data, n_future, n_steps=100):
    temp_input = list(last_data)
    temp_input = temp_input[0].tolist()
    
    lst_output = []
    i = 0
    while i < n_future:
        if len(temp_input) > n_steps:
            x_input = np.array(temp_input[1:])
            x_input = x_input.reshape(1, -1)
            x_input = x_input.reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            temp_input = temp_input[1:]
            lst_output.extend(yhat.tolist())
            i += 1
        else:
            x_input = np.array(temp_input).reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            lst_output.extend(yhat.tolist())
            i += 1
            
    return np.array(lst_output).reshape(-1, 1)

# %%
def plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, train_size, test_size, title):
    train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
    plt.plot(train_data_index, scaler.inverse_transform(train_data))

    test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
    plt.plot(test_data_index, scaler.inverse_transform(test_data))

    test_pred_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
    plt.plot(test_pred_index,scaler.inverse_transform(y_pred))

    prediect_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
    plt.plot(prediect_data_index_30, scaler.inverse_transform(lst_output[:30]))

    prediect_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
    plt.plot(prediect_data_index_60, scaler.inverse_transform(lst_output[30:60]))

    prediect_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
    plt.plot(prediect_data_index_90, scaler.inverse_transform(lst_output[60:90]))

    plt.legend(['Train', 'Test', 'Predict', 'Predict30days', 'Predict60days', 'Predict90days'])
    plt.title(title)
    plt.show()

# %%
def evaluate_model(y_test, y_pred):
    mae = metrics.mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    mape = metrics.mean_absolute_percentage_error(y_test, y_pred)*100
    return mae, rmse, mape

# %%
ratios = [0.7, 0.8, 0.6]
time_step = 100

# Results dictionary to store evaluation metrics for each ratio
results = {}

# %%
for ratio in ratios:
    # Chia dữ liệu thành tập huấn luyện và kiểm tra
    training_size = int(len(df1) * ratio)
    test_size = len(df1) - training_size
    train_data, test_data = df1[0:training_size,:], df1[training_size:len(df1),:1]

    # Tạo tập huấn luyện và kiểm tra
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, y_test = create_dataset(test_data, time_step)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Xây dựng và huấn luyện mô hình
    model = build_and_train_model(X_train, y_train, X_test, y_test)

    # Dự đoán
    y_pred = model.predict(X_test)

    # Đảo ngược quá trình chuẩn hóa
    y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_pred_inv = scaler.inverse_transform(y_pred)

    # Đánh giá mô hình
    mae, rmse, mape = evaluate_model(y_test_inv, y_pred_inv)
    results[f'Ratio {int(ratio*10)}/{10-int(ratio*10)}'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}

    # Dự đoán các giá trị trong tương lai
    last_data = test_data[-time_step:].reshape(1, -1)
    lst_output = predict_future(model, last_data, 90)

    # Vẽ biểu đồ
    plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, training_size, test_size, f"Train/Test Ratio: {int(ratio*10)}/{10-int(ratio*10)}")

# In kết quả đánh giá
for ratio, metrics in results.items():
    print(f'{ratio}: MAE = {metrics["MAE"]}, RMSE = {metrics["RMSE"]}, MAPE = {metrics["MAPE"]}')
# Out:
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0696
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0074
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0033
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0014
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.5121e-04
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.4492e-04
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.0221e-04
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.2006e-04
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.7341e-04
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.8847e-04
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.5696e-04
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.5389e-04
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.4186e-04
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.5855e-04
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.3200e-04
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.3681e-04
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.1365e-04
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.2032e-04
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.2783e-04
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1889e-04
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.2115e-04
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.1171e-04
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2964e-04
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1421e-04
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.0234e-04
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9168e-04
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9849e-04
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.1248e-04
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.1183e-04
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0446e-04
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8215e-04
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.8815e-04
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.2099e-04
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9598e-04
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8888e-04
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.9825e-04
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.8047e-04
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.8211e-04
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.7331e-04
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8318e-04
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.7736e-04
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.8883e-04
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8487e-04
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.7026e-04
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.8940e-04
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.7896e-04
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6427e-04
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.8261e-04
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.9056e-04
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.6826e-04
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.8281e-04
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.6547e-04
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.5561e-04
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.6816e-04
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.6530e-04
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5897e-04
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6583e-04
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.7038e-04
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.7994e-04
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.5551e-04
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.4548e-04
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6955e-04
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6617e-04
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.6612e-04
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5699e-04
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5396e-04
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.7121e-04
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.5851e-04
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.5776e-04
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.7284e-04
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.4157e-04
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.7375e-04
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.6428e-04
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.5814e-04
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.6379e-04
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.5896e-04
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.4736e-04
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5466e-04
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.4806e-04
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6725e-04
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.4347e-04
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.4820e-04
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.4560e-04
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.4700e-04
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5213e-04
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.5648e-04
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.3588e-04
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.5485e-04
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.4386e-04
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.4319e-04
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5156e-04
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6684e-04
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5696e-04
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.5533e-04
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.3981e-04
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.7512e-04
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.4665e-04
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.4748e-04
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.7058e-04
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5495e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.1205
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0107
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0046
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0020
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.7902e-04
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.9381e-04
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.5335e-04
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.9788e-04
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.9111e-04
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.0708e-04
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.3597e-04
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.9268e-04
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.3051e-04
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.2400e-04
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.2754e-04
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.2384e-04
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.3329e-04
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.7494e-04
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.9036e-04
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.9759e-04
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.1107e-04
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.1670e-04
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.1406e-04
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.6932e-04
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.2539e-04
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.6650e-04
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.8208e-04
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.5739e-04
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.5227e-04
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.2974e-04
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.5518e-04
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.6696e-04
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.4549e-04
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.4008e-04
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.1264e-04
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.7166e-04
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.6144e-04
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.3406e-04
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3622e-04
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.7899e-04
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.5623e-04
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.8881e-04
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.2971e-04
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.2634e-04
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.5183e-04
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.1024e-04
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.2274e-04
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.9366e-04
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.2792e-04
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.2947e-04
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.2486e-04
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.2735e-04
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.3876e-04
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.6181e-04
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.2602e-04
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 2.1159e-04
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.4280e-04
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.0308e-04
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.4785e-04
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.6906e-04
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.0965e-04
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.3106e-04
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.9991e-04
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.5177e-04
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.7763e-04
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.0825e-04
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.0637e-04
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.8101e-04
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.3401e-04
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.1414e-04
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.7840e-04
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.9481e-04
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 2.0242e-04
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.8228e-04
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.7929e-04
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.4325e-04
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.1511e-04
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.7916e-04
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9585e-04
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.4704e-04
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0427e-04
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.9539e-04
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.2084e-04
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.2824e-04
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.7674e-04
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.0053e-04
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8433e-04
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.3056e-04
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.3192e-04
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.5020e-04
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.8113e-04
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.0908e-04
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.7984e-04
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.7399e-04
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.8893e-04
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.0005e-04
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.9529e-04
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.1831e-04
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.8520e-04
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.8874e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0574
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0082
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0034
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0013
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.8522e-04
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.2655e-04
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.0261e-04
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.7099e-04
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.7691e-04
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.6591e-04
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.6171e-04
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.6875e-04
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 2.5569e-04
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.4868e-04
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.3658e-04
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.5428e-04
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.6028e-04
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.4427e-04
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2.1883e-04
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.2565e-04
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.9721e-04
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.0774e-04
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.2992e-04
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.2049e-04
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.1716e-04
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.2694e-04
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.0777e-04
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.0915e-04
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1563e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.9726e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.8605e-04
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.8530e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.9153e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.9361e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.9397e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.9822e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9385e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8039e-04
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.9569e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.9770e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 1.7562e-04
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.7475e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.8224e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.9655e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.7199e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.8776e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.6499e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7047e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.6403e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.6841e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8228e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.7148e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.7105e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5183e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.5313e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.5219e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.7459e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.7084e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.5039e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8992e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8480e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7538e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.4672e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.6996e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.5764e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.4899e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.6039e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.4409e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.6392e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.6339e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.5830e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.6633e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.4371e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.7182e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.7606e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.6859e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.5872e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.6107e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.5530e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.5144e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 1.4904e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.5336e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 1.5893e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 1.5085e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.6048e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.7707e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.7725e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.6498e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.7067e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.6293e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.5894e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.5001e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.6767e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.4022e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.7197e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.3707e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.7149e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.4537e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3695e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.4644e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Ratio 7/3: MAE = 8.814706028529576, RMSE = 11.57632306146833, MAPE = 1.0889805531470556
# Ratio 8/2: MAE = 6.289253666715797, RMSE = 9.693158808930768, MAPE = 0.7569834554388903
# Ratio 6/4: MAE = 8.7342125031002, RMSE = 12.370347504892022, MAPE = 1.1409125747314377
