# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn import metrics

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('../Datasets/VRTX_processed.csv')
df1 = df.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
def build_and_train_model(X_train, y_train):
    model = Sequential()
    model.add(GRU(64, input_shape=(100, 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')  
    model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)
    return model

# %%
def predict_future(model, last_data, n_future, n_steps=100):
    temp_input = list(last_data)
    temp_input = temp_input[0].tolist()
    
    lst_output = []
    i = 0
    while i < n_future:
        if len(temp_input) > n_steps:
            x_input = np.array(temp_input[1:])
            x_input = x_input.reshape(1, -1)
            x_input = x_input.reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            temp_input = temp_input[1:]
            lst_output.extend(yhat.tolist())
            i += 1
        else:
            x_input = np.array(temp_input).reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            lst_output.extend(yhat.tolist())
            i += 1
            
    return np.array(lst_output).reshape(-1, 1)

# %%
def plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, train_size, test_size, title):
    train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
    plt.plot(train_data_index, scaler.inverse_transform(train_data))

    test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
    plt.plot(test_data_index, scaler.inverse_transform(test_data))

    test_pred_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
    plt.plot(test_pred_index,scaler.inverse_transform(y_pred))

    prediect_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
    plt.plot(prediect_data_index_30, scaler.inverse_transform(lst_output[:30]))

    prediect_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
    plt.plot(prediect_data_index_60, scaler.inverse_transform(lst_output[30:60]))

    prediect_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
    plt.plot(prediect_data_index_90, scaler.inverse_transform(lst_output[60:90]))

    plt.legend(['Train', 'Test', 'Predict', 'Predict30days', 'Predict60days', 'Predict90days'])
    plt.title(title)
    plt.show()

# %%
def evaluate_model(y_test, y_pred):
    mae = metrics.mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    mape = metrics.mean_absolute_percentage_error(y_test, y_pred)*100
    return mae, rmse, mape

# %%
ratios = [0.7, 0.8, 0.6]
time_step = 100

# Results dictionary to store evaluation metrics for each ratio
results = {}

# %%
for ratio in ratios:
    # Chia dữ liệu thành tập huấn luyện và kiểm tra
    training_size = int(len(df1) * ratio)
    test_size = len(df1) - training_size
    train_data, test_data = df1[0:training_size,:], df1[training_size:len(df1),:1]

    # Tạo tập huấn luyện và kiểm tra
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, y_test = create_dataset(test_data, time_step)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Xây dựng và huấn luyện mô hình
    model = build_and_train_model(X_train, y_train)

    # Dự đoán
    y_pred = model.predict(X_test)

    # Đảo ngược quá trình chuẩn hóa
    y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_pred_inv = scaler.inverse_transform(y_pred)

    # Đánh giá mô hình
    mae, rmse, mape = evaluate_model(y_test_inv, y_pred_inv)
    results[f'Ratio {int(ratio*10)}/{10-int(ratio*10)}'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}

    # Dự đoán các giá trị trong tương lai
    last_data = test_data[-time_step:].reshape(1, -1)
    lst_output = predict_future(model, last_data, 90)

    # Vẽ biểu đồ
    plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, training_size, test_size, f"Train/Test Ratio: {int(ratio*10)}/{10-int(ratio*10)}")

# In kết quả đánh giá
for ratio, metrics in results.items():
    print(f'{ratio}: MAE = {metrics["MAE"]}, RMSE = {metrics["RMSE"]}, MAPE = {metrics["MAPE"]}')
# Out:
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0356
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0055
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0021
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.9971e-04
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.7453e-04
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1651e-04
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1716e-04
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.8042e-04
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.7057e-04
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.4046e-04
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.8785e-04
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.6595e-04
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.3240e-04
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.6118e-04
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.2662e-04
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.8986e-04
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.1592e-04
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.1768e-04
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.7006e-04
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.9789e-04
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.2764e-04
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.3826e-04
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.1824e-04
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.9329e-04
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.7689e-04
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.3372e-04
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.2237e-04
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.7216e-04
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.8252e-04
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.3119e-04
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.4489e-04
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.1435e-04
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.4160e-04
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.5015e-04
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.4188e-04
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.1167e-04
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.3501e-04
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.3192e-04
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.3629e-04
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.5004e-04
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.5096e-04
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.4566e-04
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.6606e-04
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.2961e-04
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.9852e-04
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.2342e-04
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3897e-04
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.1568e-04
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.4481e-04
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.9916e-04
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1841e-04
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.1598e-04
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.7731e-04
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9240e-04
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0243e-04
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.7292e-04
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.7484e-04
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.2014e-04
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.5183e-04
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.8829e-04
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.3498e-04
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1888e-04
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.4114e-04
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.9856e-04
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1217e-04
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.9911e-04
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.0793e-04
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.8288e-04
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0137e-04
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0507e-04
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.4107e-04
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.0925e-04
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.2276e-04
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.9155e-04
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.2163e-04
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.2142e-04
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7296e-04
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.6346e-04
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.0033e-04
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.1674e-04
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.0986e-04
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.0227e-04
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.7825e-04
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.1264e-04
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.8455e-04
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1096e-04
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0023e-04
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.6693e-04
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.0913e-04
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.5791e-04
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.3438e-04
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.5478e-04
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3621e-04
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.1235e-04
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.9160e-04
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.9920e-04
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1802e-04
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8745e-04
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0863e-04
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.6038e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0366
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0040
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0011
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.8686e-04
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.8441e-04
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 3.4081e-04
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 3.7372e-04
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 3.1545e-04
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.6825e-04
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 2.9725e-04
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.8914e-04
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.5322e-04
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.1213e-04
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.0829e-04
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.8837e-04
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.1534e-04
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.8948e-04
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.6607e-04
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.9737e-04
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.5320e-04
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.8974e-04
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.6477e-04
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.9183e-04
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.5896e-04
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.2831e-04
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.2632e-04
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.6103e-04
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.5458e-04
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.3191e-04
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.2534e-04
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.5895e-04
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.3909e-04
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.2913e-04
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.2582e-04
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.1683e-04
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 3.2827e-04
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 2.6616e-04
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.0744e-04
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.0982e-04
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.4210e-04
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.2795e-04
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.7193e-04
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.5699e-04
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.5966e-04
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.0508e-04
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.2951e-04
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.4895e-04
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.0365e-04
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.4125e-04
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.6599e-04
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0884e-04
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.2420e-04
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3029e-04
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.9584e-04
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.1096e-04
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.0125e-04
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.4255e-04
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.6790e-04
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.5182e-04
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.6021e-04
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.3104e-04
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.7713e-04
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.0508e-04
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3741e-04
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.9802e-04
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.1748e-04
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 2.1568e-04
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.1619e-04
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 2.4896e-04
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 2.6485e-04
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 2.5665e-04
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.9152e-04
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8648e-04
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.0938e-04
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.1988e-04
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.5376e-04
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.1217e-04
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.8354e-04
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.4454e-04
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.9299e-04
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.9390e-04
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.0786e-04
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.6203e-04
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.0844e-04
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.3551e-04
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.8446e-04
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.4095e-04
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.5298e-04
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.5481e-04
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1986e-04
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2870e-04
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1304e-04
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.0747e-04
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8651e-04
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.0097e-04
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.3761e-04
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1326e-04
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.3100e-04
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.2771e-04
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.6085e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0245
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0041
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0017
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.9666e-04
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.8408e-04
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.8965e-04
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.8140e-04
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.1240e-04
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.0704e-04
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.6340e-04
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.7890e-04
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.0819e-04
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.9552e-04
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.0676e-04
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.6629e-04
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.8958e-04
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.6652e-04
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.1665e-04
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.9649e-04
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.1368e-04
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.8150e-04
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.9237e-04
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.5227e-04
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.1682e-04
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3150e-04
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.9859e-04
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2139e-04
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.2273e-04
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.5127e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.9016e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.8289e-04
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.4039e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2642e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.8660e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.0938e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 2.4851e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.0710e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.2437e-04
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.5434e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.9711e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.2546e-04
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.9720e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.3242e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1793e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.1422e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.2143e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1169e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.5699e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.2691e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.8047e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.8373e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.8460e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5977e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1058e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1260e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.1188e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.2545e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1017e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.6869e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.7696e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8120e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.6584e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9934e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.8103e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.1456e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.6254e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.1701e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.9148e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.3480e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8960e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9364e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.4075e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.2580e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.9396e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9423e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.1571e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.9109e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.9968e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.5650e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.0057e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 2.1858e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.7235e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 2.2158e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.0796e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8749e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.0949e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.3544e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.6302e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.5593e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.8491e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3792e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.8492e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.5653e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.6339e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.9295e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.9730e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.9388e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.7669e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.6593e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.0306e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Ratio 7/3: MAE = 3.538338375091552, RMSE = 5.047823630569882, MAPE = 0.9888444017445918
# Ratio 8/2: MAE = 3.6393340534714023, RMSE = 5.323986164184572, MAPE = 0.9564287918326031
# Ratio 6/4: MAE = 3.709644116598462, RMSE = 5.148522666460205, MAPE = 1.1018539374527976
