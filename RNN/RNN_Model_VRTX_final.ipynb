# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from sklearn import metrics

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('../Datasets/VRTX_processed.csv')
df1 = df.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
def build_and_train_model(X_train, y_train):
    model = Sequential()
    model.add(SimpleRNN(50, input_shape=(time_step, 1)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error',optimizer='adam')
    model.fit(X_train,y_train,epochs=100,batch_size=64,verbose=1)
    return model

# %%
def predict_future(model, last_data, n_future, n_steps=100):
    temp_input = list(last_data)
    temp_input = temp_input[0].tolist()
    
    lst_output = []
    i = 0
    while i < n_future:
        if len(temp_input) > n_steps:
            x_input = np.array(temp_input[1:])
            x_input = x_input.reshape(1, -1)
            x_input = x_input.reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            temp_input = temp_input[1:]
            lst_output.extend(yhat.tolist())
            i += 1
        else:
            x_input = np.array(temp_input).reshape((1, n_steps, 1))
            yhat = model.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            lst_output.extend(yhat.tolist())
            i += 1
            
    return np.array(lst_output).reshape(-1, 1)

# %%
def plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, train_size, test_size, title):
    train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
    plt.plot(train_data_index, scaler.inverse_transform(train_data))

    test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
    plt.plot(test_data_index, scaler.inverse_transform(test_data))

    test_pred_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
    plt.plot(test_pred_index,scaler.inverse_transform(y_pred))

    prediect_data_index_30 = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
    plt.plot(prediect_data_index_30, scaler.inverse_transform(lst_output[:30]))

    prediect_data_index_60 = pd.RangeIndex(start=len(df1)+29, stop=len(df1)+59, step=1)
    plt.plot(prediect_data_index_60, scaler.inverse_transform(lst_output[30:60]))

    prediect_data_index_90 = pd.RangeIndex(start=len(df1)+59, stop=len(df1)+89, step=1)
    plt.plot(prediect_data_index_90, scaler.inverse_transform(lst_output[60:90]))

    plt.legend(['Train', 'Test', 'Predict', 'Predict30days', 'Predict60days', 'Predict90days'])
    plt.title(title)
    plt.show()

# %%
def evaluate_model(y_test, y_pred):
    mae = metrics.mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    mape = metrics.mean_absolute_percentage_error(y_test, y_pred)*100
    return mae, rmse, mape

# %%
ratios = [0.7, 0.8, 0.6]
time_step = 100

# Results dictionary to store evaluation metrics for each ratio
results = {}

# %%
for ratio in ratios:
    # Chia dữ liệu thành tập huấn luyện và kiểm tra
    training_size = int(len(df1) * ratio)
    test_size = len(df1) - training_size
    train_data, test_data = df1[0:training_size,:], df1[training_size:len(df1),:1]

    # Tạo tập huấn luyện và kiểm tra
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, y_test = create_dataset(test_data, time_step)

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Xây dựng và huấn luyện mô hình
    model = build_and_train_model(X_train, y_train)

    # Dự đoán
    y_pred = model.predict(X_test)

    # Đảo ngược quá trình chuẩn hóa
    y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_pred_inv = scaler.inverse_transform(y_pred)

    # Đánh giá mô hình
    mae, rmse, mape = evaluate_model(y_test_inv, y_pred_inv)
    results[f'Ratio {int(ratio*10)}/{10-int(ratio*10)}'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}

    # Dự đoán các giá trị trong tương lai
    last_data = test_data[-time_step:].reshape(1, -1)
    lst_output = predict_future(model, last_data, 90)

    # Vẽ biểu đồ
    plot_predictions(df1, scaler, train_data, test_data, y_pred, lst_output, training_size, test_size, f"Train/Test Ratio: {int(ratio*10)}/{10-int(ratio*10)}")

# In kết quả đánh giá
for ratio, metrics in results.items():
    print(f'{ratio}: MAE = {metrics["MAE"]}, RMSE = {metrics["RMSE"]}, MAPE = {metrics["MAPE"]}')
# Out:
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0762
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.0160e-04
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.3400e-04
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.9181e-04
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.0572e-04
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.4807e-04
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.6360e-04
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.1992e-04
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.7038e-04
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9146e-04
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0907e-04
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.4711e-04
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9127e-04
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1491e-04
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3656e-04
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4925e-04
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3500e-04
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0367e-04
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5681e-04
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.7549e-04
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.4901e-04
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6543e-04
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.9002e-04
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6944e-04
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.5871e-04
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.6545e-04
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.9387e-04
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.2909e-04
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.7979e-04
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.9528e-04
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4646e-04
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.3307e-04
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9166e-04
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3626e-04
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2061e-04
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2733e-04
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0741e-04
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.9762e-04
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8671e-04
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.7925e-04
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.7982e-04
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4282e-04
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.9199e-04
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7496e-04
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6093e-04
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.0010e-04
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7373e-04
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9608e-04
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.2842e-04
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9161e-04
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3068e-04
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.2346e-04
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.4867e-04
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6876e-04
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.9343e-04
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5487e-04
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6322e-04
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7556e-04
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.5136e-04
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 2.3140e-04
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.1903e-04
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2836e-04
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.2415e-04
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7761e-04
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.6293e-04
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.2461e-04
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.0905e-04
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.1259e-04
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.5606e-04
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4802e-04
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6333e-04
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5249e-04
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3561e-04
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5358e-04
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3244e-04
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3301e-04
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1326e-04
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3794e-04
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3186e-04
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3539e-04
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.0343e-04
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.1665e-04
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.4010e-04
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.2206e-04
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.2860e-04
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.5462e-04
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.4709e-04
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.1767e-04
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 2.2704e-04
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.1557e-04
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.9127e-04
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.0013e-04
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6354e-04
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2868e-04
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9646e-04
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.6527e-04
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4370e-04
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.6182e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0055
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.6309e-04
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.6922e-04
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.8297e-04
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.3400e-04
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.8749e-04
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6399e-04
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.0319e-04
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 4.0023e-04
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9724e-04
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8386e-04
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3166e-04
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.6390e-04
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2986e-04
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.7745e-04
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0243e-04
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.0530e-04
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.1120e-04
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3341e-04
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.8018e-04
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6987e-04
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7364e-04
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6337e-04
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.0232e-04
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.6338e-04
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5297e-04
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2072e-04
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1122e-04
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.2625e-04
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.3622e-04
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.9883e-04
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.4085e-04
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.2200e-04
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2194e-04
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.6263e-04
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0540e-04
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1366e-04
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.9584e-04
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9756e-04
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.7372e-04
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1022e-04
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1575e-04
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.6220e-04
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8881e-04
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1971e-04
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0014e-04
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0351e-04
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9212e-04
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4872e-04
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0906e-04
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0349e-04
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.4554e-04
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.0501e-04
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2130e-04
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.3028e-04
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.3709e-04
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.2739e-04
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.8955e-04
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8789e-04
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.4964e-04
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.8216e-04
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.9856e-04
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.8594e-04
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0613e-04
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7822e-04
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4039e-04
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7781e-04
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9503e-04
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8603e-04
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3621e-04
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.6964e-04
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0994e-04
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.0718e-04
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9869e-04
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9316e-04
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3009e-04
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0586e-04
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8336e-04
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5892e-04
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8434e-04
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1834e-04
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3715e-04
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1699e-04
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8216e-04
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1655e-04
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6436e-04
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9932e-04
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8848e-04
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1292e-04
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7983e-04
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7268e-04
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8430e-04
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.0054e-04
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3783e-04
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.7225e-04
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.1347e-04
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.9719e-04
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.5120e-04
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.8684e-04
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6865e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step
# Epoch 1/100
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0166
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.3726e-04
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9215e-04
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.5059e-04
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.1717e-04
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.9661e-04
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.2400e-04
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5783e-04
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5059e-04
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8898e-04
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3421e-04
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8888e-04
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3419e-04
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3270e-04
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.0240e-04
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.0480e-04
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.2750e-04
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3273e-04
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.2969e-04
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1031e-04
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1139e-04
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4209e-04
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1648e-04
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1863e-04
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1788e-04
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7747e-04
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.2777e-04
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6585e-04
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3385e-04
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9320e-04
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1921e-04
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.7361e-04
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3073e-04
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7666e-04
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6201e-04
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8144e-04
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1294e-04
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3492e-04
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4429e-04
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.7574e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4996e-04
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6908e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8758e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9706e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3956e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6431e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4901e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7952e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.8078e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.9998e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0284e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1360e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.7155e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2854e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4760e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4548e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4859e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3104e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0686e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8173e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8277e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2346e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5718e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6555e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3695e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0458e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2802e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0785e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9430e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2334e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2773e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1400e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9952e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9850e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0094e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1380e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4681e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5617e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2936e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6741e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7581e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3277e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8528e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2669e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1061e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.7971e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1192e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6895e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8346e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2083e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9742e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5877e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0102e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5758e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2821e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8892e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8492e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8050e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Ratio 7/3: MAE = 4.845567520686557, RMSE = 6.470730736953121, MAPE = 1.339184780252765
# Ratio 8/2: MAE = 4.140476884949883, RMSE = 5.934153409019375, MAPE = 1.0671623918174846
# Ratio 6/4: MAE = 6.513258835565476, RMSE = 8.117350116191217, MAPE = 1.8893597600007237
